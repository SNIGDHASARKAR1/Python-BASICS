# %% [markdown]
# **PYTHON BASIC**

# %% [markdown]
# Q1.  What is Python and why is it popular?
#      -  Python is a general purpose programming language that is used to build software and websites,automate tasks and analyze data.
#       Python is popular because of the following factors-
#       i.It is easy to learn ,
#       ii. It has an active, supportive community,
#       iii. It is flexible,
#       iv. It offers versatile web-developmental solutions,
#
# Q2. What is an interpreter in Python?
#     -   A Python interpreter is a program that reads and executes
#       python code line by line.
#
# Q3. What are pre-defined keywords in Python?
#     -   Pre define keywords are used to define the syntax of the
#       coding. Keywords are- False, True, import, if, class, except, etc.
#
# Q4. Can keywords be used as variable name?
#      - No , keywords cannot be used as  variable names.
#
# Q5. What is mutability in Python?
#      - In Python, mutability refers to the ability to change the
#        value or state of an object after it has been created.
#
# Q6. Why are lists are mutable, but tuples are immutable?
#     -  Lists can be modified after creation whereas tuples once created cananot be changed.
#
# Q7. What is the difference between "==" and "is" operators in
#     Python?
#    -    The "==" operator is used to compare the values of two
#       objects.
#      It checks whether the values of the objects are equal.
#      The "is" operator is used to compare the identity of two objects. It checks whether the two variables point to the same object in memory. This operator is often used to check if a variable is None.
#
# Q8. What are logical operators in Python?
#    -  Logical operators in Python are used to combine conditional
#       statements. They are essential for controlling the flow of your program based on multiple conditions. Here are the three main logical operators in Python: and , or, not.
#
# Q9. What is type casting in python?
#    - Type casting, also known as type conversion, is the process of
#      converting a variable from one data type to another. In Python, this can be done either implicitly or explicitly.
#      Eg- int(), str(), list(), etc
#
# Q10. What is the difference between implicit and explicit type
#      casting?
#    - In implicit type conversion, Python automatically converts one
#      data type to another without any user intervention. This usually happens when performing operations involving mixed data types to prevent data loss.
#      Explicit type conversion requires the user to manually convert the data type using predefined functions like int(), float(), and str().
#
# Q11. What is the purpose of conditional statements in Python?
#      - Conditional statements in Python allow you to execute code
#        based on certain conditions. The primary conditional statements are if, elif, and else.
# Q12. How does the elif statement work?
#      - The elif (short for else if) statement allows us to check
#       multiple conditions.
#      eg-
#        a = 33
#        b = 33
#        if b > a:
#        print("b is greater than a")
#        elif a == b:
#        print("a and b are equal")
#        else:
#        print("a is greater than b")
#
# Q13. What is the difference between for and while loop?
#     - for loop is used when you know the number of iterations in    advance or when iterating over a sequence (like a list, tuple, dictionary, set, or string).
#      Syntax:
#
#        for element in iterable:
#            # Code block to execute
#      while loop is used when the number of iterations is not known in advance and depends on a condition being true or false.
#      Syntax:
#
#        while condition:
#           # Code block to execute
#
# Q14. Describe a scenario where while loop is more suitable than a for
#    loop.

# %%
# 1. write a python program to print "Hello,World!"

      print("Hello, World!")

#2. write a python program that displays your name and age

     def print_name_and_age():
      # Prompt the user to enter their name
      name = input("Please enter your name: ")

      # Prompt the user to enter their age
      age = input("Please enter your age: ")

      # Print the name and age
      print(f"Name: {name}, Age: {age}")

      # Call the function
       print_name_and_age()

#3. write a code to print all the pre defined keywords in Python using the keyword library

      import keyword

         # Print all predefined keywords in Python
          print(keyword.kwlist)

#4. write a program that checks if a given word is a Python keyword

     import keyword

      s = 'for'

      # Check if it's a Python keyword
        if keyword.iskeyword(s):
          print(f"'{s}' is a Python keyword.")
        else:
          print(f"'{s}' is not a Python keyword.")

#5.  create a list and tuple in python, and demonstrate how attempting to chaange an element works differently for each
     # Creating a list
       my_list = [1, 2, 3, 4, 5]
    # Changing the second element (index 1) from 2 to 20
       my_list[1] = 20
       print(my_list)

       # Creating a tuple
         my_tuple = (1, 2, 3, 4, 5)

         # Tuples are immutable, so you cannot change an element directly.
         # Instead, you can create a new tuple with the desired changes.
         # Changing the second element (index 1) from 2 to 20
         new_tuple = my_tuple[:1] + (20,) + my_tuple[2:]
         print(new_tuple)

#6. write a function to demonstrate the behavior of mutable and immutable arguments
      # Immutable argument (integer)
    immutable_value = 5
    print("Before calling modify_immutable:")
    print(f"immutable_value: {immutable_value}")
    modify_immutable(immutable_value)
    print("After calling modify_immutable:")
    print(f"immutable_value: {immutable_value}\n")

    # Mutable argument (list)
    mutable_list = [1, 2, 3]
    print("Before calling modify_mutable:")
    print(f"mutable_list: {mutable_list}")
    modify_mutable(mutable_list)
    print("After calling modify_mutable:")
    print(f"mutable_list: {mutable_list}")

#8. write a program to demonstrate the use of logical operators.
     # Define some variables
       a = True
       b = False
       # Using 'and' operator
        and_result = a and b
        print(f"{a} and {b} is {and_result}")

       # Using 'or' operator
        or_result = a or b
        print(f"{a} or {b} is {or_result}")

       # Using 'not' operator
        not_result = not a
        print(f"not {a} is {not_result}")

       # Combining logical operators
        combined_result = (a and b) or (not b)
        print(f"({a} and {b}) or (not {b}) is {combined_result}")

#9.write a python program to convert user input  from string to integer, float and boolean types
     def convert_input(user_input):
    try:
        int_value = int(user_input)
    except ValueError:
        int_value = None

    try:
        float_value = float(user_input)
    except ValueError:
        float_value = None

    if user_input.lower() in ['true', 'false']:
        bool_value = user_input.lower() == 'true'
    else:
        bool_value = None

    return int_value, float_value, bool_value

    # Get user input
    user_input = input("Enter a value: ")

    # Convert the input
    int_value, float_value, bool_value = convert_input(user_input)

    # Display the results
    print(f"Integer conversion: {int_value}")
    print(f"Float conversion: {float_value}")
    print(f"Boolean conversion: {bool_value}")

#10. write a code to demonstrate type casting with list elements
     # Original list with string elements
      string_list = ['1', '2', '3', '4', '5']

     # Convert string elements to integers
       int_list = [int(element) for element in string_list]
       print("List with integer elements:", int_list)

     # Convert integer elements back to strings
       string_list_again = [str(element) for element in int_list]
       print("List with string elements:", string_list_again)

     # Original list with mixed type elements
       mixed_list = ['1', 2, '3', 4.0, '5']

     # Convert all elements to strings
       all_strings = [str(element) for element in mixed_list]
       print("List with all string elements:", all_strings)

    # Convert all elements to floats
       all_floats = [float(element) for element in mixed_list]
       print("List with all float elements:", all_floats)

#11. write a program that checks if a number is positive, negative or zero.
     def check_number(num):
    if num > 0:
        return "The number is positive."
    elif num < 0:
        return "The number is negative."
    else:
        return "The number is zero."

   # Input from the user
      number = float(input("Enter a number: "))

   # Check the number and print the result
     result = check_number(number)
     print(result)

#12.write a for loop to print numbers 1 to 10
      for i in range(1, 11):
       print(i)

#13. write a python program to find the the sum of all even numbers between 1 and 50

     # Initialize the sum variable
      sum_of_evens = 0

     # Loop through numbers from 1 to 50
      for number in range(1, 51):
     # Check if the number is even
      if number % 2 == 0:
    # Add the even number to the sum
         sum_of_evens += number

     # Print the result
        print("The sum of all even numbers between 1 and 50 is:", sum_of_evens)

#14. write a program to reverse a string using a while loop

      def reverse_string(input_string):
     # Initialize an empty string to store the reversed string
      reversed_string = ""

     # Get the length of the input string
      length = len(input_string)

    # Initialize the index to the last character of the input string
      index = length - 1

    # Use a while loop to iterate through the string in reverse order
    while index >= 0:
        # Append the current character to the reversed string
        reversed_string += input_string[index]
        # Decrement the index to move to the previous character
        index -= 1

    return reversed_string

#15. write a python program to calculate the factorial of a number provided by the user using a while loop.

     # Function to calculate factorial using a while loop
     def factorial(n):
       result = 1
       while n > 0:
        result *= n
        n -= 1
    return result

     # Main program
      try:
     # Taking input from the user
      number = int(input("Enter a number to calculate its factorial: "))

      if number < 0:
        print("Factorial is not defined for negative numbers.")
      else:
        # Calculating factorial
        fact = factorial(number)
        print(f"The factorial of {number} is {fact}.")
      except ValueError:
        print("Please enter a valid integer.")
# Out:
#   File "<tokenize>", line 7
#     def print_name_and_age():
#     ^
# IndentationError: unindent does not match any outer indentation level
